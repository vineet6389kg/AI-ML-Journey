# %%
import pandas as pd

# %%
info = {
    "Name" : ["Rahul","Shraddha","Aman","rahul"],
    "CGPA" : [9.5,7.5,8.5,7]
}

df = pd.DataFrame(info)
print(df)
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1  Shraddha   7.5
# 2      Aman   8.5
# 3     rahul   7.0

# %%
df
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1  Shraddha   7.5
# 2      Aman   8.5
# 3     rahul   7.0

# %%
df = pd.DataFrame([["adam",25],["bob",35],["eve",30]], Coloumns["Name","Age"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.DataFrame([["adam",25],["bob",35],["eve",30]], Coloumns["Name","Age"])
#
# NameError: name 'Coloumns' is not defined
